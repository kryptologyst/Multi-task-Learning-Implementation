# %% [markdown]
# # Multi-task Learning Tutorial
#
# This notebook demonstrates how to use the multi-task learning framework.
#
# **Author:** [kryptologyst](https://github.com/kryptologyst)
# **GitHub:** https://github.com/kryptologyst
#
# ## ⚠️ Safety Disclaimer
#
# This is a research demonstration only. Not suitable for production decisions.
